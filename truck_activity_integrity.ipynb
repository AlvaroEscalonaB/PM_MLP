# %%
import pandas as pd

# %%
from event_log_integrity import overlap_metric, events_contained_metric

# %%
df_log = pd.read_csv('data/full_event_log_v3.csv', parse_dates=['timestamp', 'timestamp_end'])

# %%
overlap_metric(df_log)
events_contained_metric(df_log);
# Out:
# Overlap Metric: 2.49%
# Entirely contained events: 2.03%

# %% [markdown]
# Esto dice que en un ~2.49% de las actividades en este caso (`case_id` como `truck_id`) la actividad siguiente comienza, mientras no termina la anterior. De la misma manera, las actividades contenidas en otras, es decir que comienzan después pero que terminan antes que la primera es de un 2.03%.
