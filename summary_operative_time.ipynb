# %%
import pandas as pd

# %%
FILE = 'data/CAEXSummaryTimes.csv'
df = pd.read_csv(FILE, encoding='latin-1')

# %%
print(df[df['reason'] != 'Efectivo']['total_duration'].sum(), 'horas')
# Out:
# 12432.5 horas

# %%
df[['reason', 'total_duration']]
# Out:
#                              reason  total_duration
# 0                          Efectivo         23751.4
# 1               Mecanica imprevista          1803.0
# 2             Mantencion programada          1377.0
# 3                Falla motor diesel          1164.8
# 4      Sin infraestructura de apoyo           930.5
# 5                   Cambio de turno           842.4
# 6               Colacion en comedor           839.6
# 7                   Pista obstruida           818.5
# 8              COLACION EN CABINA 2           702.2
# 9             Sin equipo de carguio           576.5
# 10        Operador fuera del equipo           500.9
# 11             COLACION EN CABINA 1           414.4
# 12             Carga de combustible           270.7
# 13        CON OPERADOR NO REQUERIDO           259.4
# 14    SIN OPERADOR / FUERA DE FAENA           252.5
# 15               Relevo de operador           146.2
# 16    Reparacion equipo accidentado           135.3
# ...
